# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities_data = pd.DataFrame({"City":cities}) 
cities_data = cities_data.drop_duplicates('City')
cities_data.head()
# Out:
#             City
# 0        rikitea
# 1         geneva
# 2       dzhusaly
# 3  leningradskiy
# 4       saldanha

# %%
cities_data["Lat"] = ""
cities_data["Lon"] = ""
cities_data["Date"] = ""
cities_data["Temp"] = ""
cities_data["Humidity"] = ""
cities_data["Cloudiness"] = ""
cities_data["Windspeed"] = ""

cities_data.head()
# Out:
#             City Lat Lon Date Temp Humidity Cloudiness Windspeed
# 0        rikitea
# 1         geneva
# 2       dzhusaly
# 3  leningradskiy
# 4       saldanha

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
row_num = 0

# Loop through the cities and perform API Calls
for index, row in cities_data.iterrows():
    base_url = "http://api.openweathermap.org/data/2.5/weather?q=%s&units=IMPERIAL&appid=%s" %(row["City"], api_key)
    response = requests.get(base_url).json()
    print("Now retrieving city #%s: %s" % (row_num + 1, cities_data.loc[index]["City"]))
    print(base_url)
    row_num += 1
    
    try:    
        cities_data.set_value(index, "Lat", response["coord"]["lat"])
        cities_data.set_value(index, "Lon", response["coord"]["lon"])
        cities_data.set_value(index, "Date", response["dt"])
        cities_data.set_value(index, "Humidity", response["main"]["humidity"])
        cities_data.set_value(index, "Temp", response["main"]["temp"])
        cities_data.set_value(index, "Windspeed", response["wind"]["speed"])
        cities_data.set_value(index, "Cloudiness", response["clouds"]["all"])
           
    except:
        print("error skip.")
# Out:
# Now retrieving city #1: rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# C:\Users\tharu\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if sys.path[0] == '':
# C:\Users\tharu\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# C:\Users\tharu\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# C:\Users\tharu\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
# C:\Users\tharu\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   app.launch_new_instance()
# C:\Users\tharu\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\tharu\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# Now retrieving city #2: geneva
# http://api.openweathermap.org/data/2.5/weather?q=geneva&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #3: dzhusaly
# http://api.openweathermap.org/data/2.5/weather?q=dzhusaly&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #4: leningradskiy
# http://api.openweathermap.org/data/2.5/weather?q=leningradskiy&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #5: saldanha
# http://api.openweathermap.org/data/2.5/weather?q=saldanha&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #6: tiznit
# http://api.openweathermap.org/data/2.5/weather?q=tiznit&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #7: calama
# http://api.openweathermap.org/data/2.5/weather?q=calama&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #8: norman wells
# http://api.openweathermap.org/data/2.5/weather?q=norman wells&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #9: ponta do sol
# http://api.openweathermap.org/data/2.5/weather?q=ponta do sol&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #10: hithadhoo
# http://api.openweathermap.org/data/2.5/weather?q=hithadhoo&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #11: busselton
# http://api.openweathermap.org/data/2.5/weather?q=busselton&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #12: seymchan
# http://api.openweathermap.org/data/2.5/weather?q=seymchan&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #13: fortuna
# http://api.openweathermap.org/data/2.5/weather?q=fortuna&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #14: marion
# http://api.openweathermap.org/data/2.5/weather?q=marion&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #15: hobart
# http://api.openweathermap.org/data/2.5/weather?q=hobart&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #16: mataura
# http://api.openweathermap.org/data/2.5/weather?q=mataura&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #17: kieta
# http://api.openweathermap.org/data/2.5/weather?q=kieta&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #18: cheuskiny
# http://api.openweathermap.org/data/2.5/weather?q=cheuskiny&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #19: honiara
# http://api.openweathermap.org/data/2.5/weather?q=honiara&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #20: ribeira grande
# http://api.openweathermap.org/data/2.5/weather?q=ribeira grande&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #21: qaanaaq
# http://api.openweathermap.org/data/2.5/weather?q=qaanaaq&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #22: chokurdakh
# http://api.openweathermap.org/data/2.5/weather?q=chokurdakh&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #23: sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?q=sentyabrskiy&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #24: cape town
# http://api.openweathermap.org/data/2.5/weather?q=cape town&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #25: east london
# http://api.openweathermap.org/data/2.5/weather?q=east london&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #26: jamestown
# http://api.openweathermap.org/data/2.5/weather?q=jamestown&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #27: kodiak
# http://api.openweathermap.org/data/2.5/weather?q=kodiak&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #28: debre tabor
# http://api.openweathermap.org/data/2.5/weather?q=debre tabor&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #29: eyl
# http://api.openweathermap.org/data/2.5/weather?q=eyl&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #30: hermanus
# http://api.openweathermap.org/data/2.5/weather?q=hermanus&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #31: longyearbyen
# http://api.openweathermap.org/data/2.5/weather?q=longyearbyen&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #32: quelimane
# http://api.openweathermap.org/data/2.5/weather?q=quelimane&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #33: baykit
# http://api.openweathermap.org/data/2.5/weather?q=baykit&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #34: nikolskoye
# http://api.openweathermap.org/data/2.5/weather?q=nikolskoye&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #35: indiaroba
# http://api.openweathermap.org/data/2.5/weather?q=indiaroba&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #36: kotelnich
# http://api.openweathermap.org/data/2.5/weather?q=kotelnich&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #37: punta arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta arenas&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #38: vaini
# http://api.openweathermap.org/data/2.5/weather?q=vaini&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #39: mullaitivu
# http://api.openweathermap.org/data/2.5/weather?q=mullaitivu&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #40: visby
# http://api.openweathermap.org/data/2.5/weather?q=visby&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #41: barentsburg
# http://api.openweathermap.org/data/2.5/weather?q=barentsburg&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #42: viedma
# http://api.openweathermap.org/data/2.5/weather?q=viedma&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #43: grand river south east
# http://api.openweathermap.org/data/2.5/weather?q=grand river south east&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #44: mar del plata
# http://api.openweathermap.org/data/2.5/weather?q=mar del plata&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #45: torbay
# http://api.openweathermap.org/data/2.5/weather?q=torbay&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #46: ahipara
# http://api.openweathermap.org/data/2.5/weather?q=ahipara&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #47: kazalinsk
# http://api.openweathermap.org/data/2.5/weather?q=kazalinsk&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #48: rawson
# http://api.openweathermap.org/data/2.5/weather?q=rawson&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #49: castro
# http://api.openweathermap.org/data/2.5/weather?q=castro&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #50: te anau
# http://api.openweathermap.org/data/2.5/weather?q=te anau&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #51: vaitape
# http://api.openweathermap.org/data/2.5/weather?q=vaitape&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #52: adrar
# http://api.openweathermap.org/data/2.5/weather?q=adrar&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #53: sibolga
# http://api.openweathermap.org/data/2.5/weather?q=sibolga&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #54: mys shmidta
# http://api.openweathermap.org/data/2.5/weather?q=mys shmidta&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #55: port alfred
# http://api.openweathermap.org/data/2.5/weather?q=port alfred&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #56: tessalit
# http://api.openweathermap.org/data/2.5/weather?q=tessalit&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #57: tres lagoas
# http://api.openweathermap.org/data/2.5/weather?q=tres lagoas&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #58: bluff
# http://api.openweathermap.org/data/2.5/weather?q=bluff&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #59: illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?q=illoqqortoormiut&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #60: sao filipe
# http://api.openweathermap.org/data/2.5/weather?q=sao filipe&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #61: alta floresta
# http://api.openweathermap.org/data/2.5/weather?q=alta floresta&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #62: mattru
# http://api.openweathermap.org/data/2.5/weather?q=mattru&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #63: acapulco
# http://api.openweathermap.org/data/2.5/weather?q=acapulco&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #64: mahebourg
# http://api.openweathermap.org/data/2.5/weather?q=mahebourg&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #65: tucuman
# http://api.openweathermap.org/data/2.5/weather?q=tucuman&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #66: tasiilaq
# http://api.openweathermap.org/data/2.5/weather?q=tasiilaq&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #67: vidim
# http://api.openweathermap.org/data/2.5/weather?q=vidim&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #68: nchelenge
# http://api.openweathermap.org/data/2.5/weather?q=nchelenge&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #69: mezen
# http://api.openweathermap.org/data/2.5/weather?q=mezen&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #70: algiers
# http://api.openweathermap.org/data/2.5/weather?q=algiers&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #71: tumannyy
# http://api.openweathermap.org/data/2.5/weather?q=tumannyy&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #72: noumea
# http://api.openweathermap.org/data/2.5/weather?q=noumea&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #73: yellowknife
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #74: mercedes
# http://api.openweathermap.org/data/2.5/weather?q=mercedes&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #75: mount gambier
# http://api.openweathermap.org/data/2.5/weather?q=mount gambier&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #76: nortelandia
# http://api.openweathermap.org/data/2.5/weather?q=nortelandia&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #77: faanui
# http://api.openweathermap.org/data/2.5/weather?q=faanui&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #78: bredasdorp
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #79: polunochnoye
# http://api.openweathermap.org/data/2.5/weather?q=polunochnoye&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #80: harper
# http://api.openweathermap.org/data/2.5/weather?q=harper&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #81: hasaki
# http://api.openweathermap.org/data/2.5/weather?q=hasaki&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #82: dikson
# http://api.openweathermap.org/data/2.5/weather?q=dikson&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #83: samusu
# http://api.openweathermap.org/data/2.5/weather?q=samusu&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #84: mayumba
# http://api.openweathermap.org/data/2.5/weather?q=mayumba&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #85: sola
# http://api.openweathermap.org/data/2.5/weather?q=sola&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #86: butaritari
# http://api.openweathermap.org/data/2.5/weather?q=butaritari&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #87: belushya guba
# http://api.openweathermap.org/data/2.5/weather?q=belushya guba&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #88: acajutla
# http://api.openweathermap.org/data/2.5/weather?q=acajutla&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #89: coquimbo
# http://api.openweathermap.org/data/2.5/weather?q=coquimbo&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #90: suntar
# http://api.openweathermap.org/data/2.5/weather?q=suntar&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #91: saskylakh
# http://api.openweathermap.org/data/2.5/weather?q=saskylakh&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #92: albany
# http://api.openweathermap.org/data/2.5/weather?q=albany&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #93: khasan
# http://api.openweathermap.org/data/2.5/weather?q=khasan&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #94: haysville
# http://api.openweathermap.org/data/2.5/weather?q=haysville&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #95: tezu
# http://api.openweathermap.org/data/2.5/weather?q=tezu&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #96: miyako
# http://api.openweathermap.org/data/2.5/weather?q=miyako&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #97: hobyo
# http://api.openweathermap.org/data/2.5/weather?q=hobyo&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #98: mabaruma
# http://api.openweathermap.org/data/2.5/weather?q=mabaruma&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #99: iqaluit
# http://api.openweathermap.org/data/2.5/weather?q=iqaluit&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #100: narsaq
# http://api.openweathermap.org/data/2.5/weather?q=narsaq&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #101: jining
# http://api.openweathermap.org/data/2.5/weather?q=jining&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #102: ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #103: olafsvik
# http://api.openweathermap.org/data/2.5/weather?q=olafsvik&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #104: comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?q=comodoro rivadavia&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #105: khatanga
# http://api.openweathermap.org/data/2.5/weather?q=khatanga&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #106: vila velha
# http://api.openweathermap.org/data/2.5/weather?q=vila velha&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #107: avarua
# http://api.openweathermap.org/data/2.5/weather?q=avarua&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #108: carutapera
# http://api.openweathermap.org/data/2.5/weather?q=carutapera&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #109: dhidhdhoo
# http://api.openweathermap.org/data/2.5/weather?q=dhidhdhoo&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #110: hami
# http://api.openweathermap.org/data/2.5/weather?q=hami&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #111: road town
# http://api.openweathermap.org/data/2.5/weather?q=road town&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #112: taolanaro
# http://api.openweathermap.org/data/2.5/weather?q=taolanaro&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #113: nouadhibou
# http://api.openweathermap.org/data/2.5/weather?q=nouadhibou&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #114: iracoubo
# http://api.openweathermap.org/data/2.5/weather?q=iracoubo&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #115: kaitangata
# http://api.openweathermap.org/data/2.5/weather?q=kaitangata&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #116: bethel
# http://api.openweathermap.org/data/2.5/weather?q=bethel&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #117: candawaga
# http://api.openweathermap.org/data/2.5/weather?q=candawaga&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #118: nanortalik
# http://api.openweathermap.org/data/2.5/weather?q=nanortalik&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #119: kununurra
# http://api.openweathermap.org/data/2.5/weather?q=kununurra&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #120: seltso
# http://api.openweathermap.org/data/2.5/weather?q=seltso&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #121: verkhnyaya inta
# http://api.openweathermap.org/data/2.5/weather?q=verkhnyaya inta&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #122: souillac
# http://api.openweathermap.org/data/2.5/weather?q=souillac&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #123: xining
# http://api.openweathermap.org/data/2.5/weather?q=xining&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #124: lagoa
# http://api.openweathermap.org/data/2.5/weather?q=lagoa&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #125: kendari
# http://api.openweathermap.org/data/2.5/weather?q=kendari&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #126: atuona
# http://api.openweathermap.org/data/2.5/weather?q=atuona&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #127: upernavik
# http://api.openweathermap.org/data/2.5/weather?q=upernavik&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #128: yar-sale
# http://api.openweathermap.org/data/2.5/weather?q=yar-sale&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #129: port macquarie
# http://api.openweathermap.org/data/2.5/weather?q=port macquarie&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #130: ostrovskoye
# http://api.openweathermap.org/data/2.5/weather?q=ostrovskoye&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #131: gravdal
# http://api.openweathermap.org/data/2.5/weather?q=gravdal&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #132: belmonte
# http://api.openweathermap.org/data/2.5/weather?q=belmonte&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #133: beruni
# http://api.openweathermap.org/data/2.5/weather?q=beruni&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #134: severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?q=severo-kurilsk&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #135: kapaa
# http://api.openweathermap.org/data/2.5/weather?q=kapaa&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #136: kruisfontein
# http://api.openweathermap.org/data/2.5/weather?q=kruisfontein&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #137: shebunino
# http://api.openweathermap.org/data/2.5/weather?q=shebunino&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #138: jizan
# http://api.openweathermap.org/data/2.5/weather?q=jizan&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #139: bima
# http://api.openweathermap.org/data/2.5/weather?q=bima&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #140: saint-philippe
# http://api.openweathermap.org/data/2.5/weather?q=saint-philippe&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #141: satun
# http://api.openweathermap.org/data/2.5/weather?q=satun&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #142: kribi
# http://api.openweathermap.org/data/2.5/weather?q=kribi&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #143: svetlogorsk
# http://api.openweathermap.org/data/2.5/weather?q=svetlogorsk&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #144: nishihara
# http://api.openweathermap.org/data/2.5/weather?q=nishihara&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #145: siguiri
# http://api.openweathermap.org/data/2.5/weather?q=siguiri&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #146: arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?q=arraial do cabo&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #147: carnarvon
# http://api.openweathermap.org/data/2.5/weather?q=carnarvon&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #148: maidstone
# http://api.openweathermap.org/data/2.5/weather?q=maidstone&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #149: upata
# http://api.openweathermap.org/data/2.5/weather?q=upata&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #150: provideniya
# http://api.openweathermap.org/data/2.5/weather?q=provideniya&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #151: camrose
# http://api.openweathermap.org/data/2.5/weather?q=camrose&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #152: vila do maio
# http://api.openweathermap.org/data/2.5/weather?q=vila do maio&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #153: lebu
# http://api.openweathermap.org/data/2.5/weather?q=lebu&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #154: santo antonio do ica
# http://api.openweathermap.org/data/2.5/weather?q=santo antonio do ica&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #155: new norfolk
# http://api.openweathermap.org/data/2.5/weather?q=new norfolk&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #156: puerto ayora
# http://api.openweathermap.org/data/2.5/weather?q=puerto ayora&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #157: grindavik
# http://api.openweathermap.org/data/2.5/weather?q=grindavik&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #158: portland
# http://api.openweathermap.org/data/2.5/weather?q=portland&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #159: neftegorsk
# http://api.openweathermap.org/data/2.5/weather?q=neftegorsk&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #160: vikhorevka
# http://api.openweathermap.org/data/2.5/weather?q=vikhorevka&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #161: georgetown
# http://api.openweathermap.org/data/2.5/weather?q=georgetown&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #162: rawannawi
# http://api.openweathermap.org/data/2.5/weather?q=rawannawi&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #163: brindisi
# http://api.openweathermap.org/data/2.5/weather?q=brindisi&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #164: buariki
# http://api.openweathermap.org/data/2.5/weather?q=buariki&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #165: thompson
# http://api.openweathermap.org/data/2.5/weather?q=thompson&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #166: andevoranto
# http://api.openweathermap.org/data/2.5/weather?q=andevoranto&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #167: hilo
# http://api.openweathermap.org/data/2.5/weather?q=hilo&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #168: tasbuget
# http://api.openweathermap.org/data/2.5/weather?q=tasbuget&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #169: yerbogachen
# http://api.openweathermap.org/data/2.5/weather?q=yerbogachen&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #170: vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?q=vila franca do campo&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #171: saint george
# http://api.openweathermap.org/data/2.5/weather?q=saint george&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #172: yeppoon
# http://api.openweathermap.org/data/2.5/weather?q=yeppoon&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #173: elizabeth city
# http://api.openweathermap.org/data/2.5/weather?q=elizabeth city&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #174: bose
# http://api.openweathermap.org/data/2.5/weather?q=bose&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #175: tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #176: dalbandin
# http://api.openweathermap.org/data/2.5/weather?q=dalbandin&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #177: coihaique
# http://api.openweathermap.org/data/2.5/weather?q=coihaique&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #178: imbituba
# http://api.openweathermap.org/data/2.5/weather?q=imbituba&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #179: calvinia
# http://api.openweathermap.org/data/2.5/weather?q=calvinia&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #180: constitucion
# http://api.openweathermap.org/data/2.5/weather?q=constitucion&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #181: alofi
# http://api.openweathermap.org/data/2.5/weather?q=alofi&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #182: ust-omchug
# http://api.openweathermap.org/data/2.5/weather?q=ust-omchug&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #183: ilulissat
# http://api.openweathermap.org/data/2.5/weather?q=ilulissat&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #184: bonthe
# http://api.openweathermap.org/data/2.5/weather?q=bonthe&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #185: kampot
# http://api.openweathermap.org/data/2.5/weather?q=kampot&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #186: totoro
# http://api.openweathermap.org/data/2.5/weather?q=totoro&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #187: wilmington
# http://api.openweathermap.org/data/2.5/weather?q=wilmington&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #188: burica
# http://api.openweathermap.org/data/2.5/weather?q=burica&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #189: teya
# http://api.openweathermap.org/data/2.5/weather?q=teya&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #190: port-gentil
# http://api.openweathermap.org/data/2.5/weather?q=port-gentil&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #191: pangnirtung
# http://api.openweathermap.org/data/2.5/weather?q=pangnirtung&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #192: havoysund
# http://api.openweathermap.org/data/2.5/weather?q=havoysund&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #193: guerrero negro
# http://api.openweathermap.org/data/2.5/weather?q=guerrero negro&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #194: mtinko
# http://api.openweathermap.org/data/2.5/weather?q=mtinko&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #195: kuytun
# http://api.openweathermap.org/data/2.5/weather?q=kuytun&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #196: cidreira
# http://api.openweathermap.org/data/2.5/weather?q=cidreira&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #197: tavda
# http://api.openweathermap.org/data/2.5/weather?q=tavda&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #198: broome
# http://api.openweathermap.org/data/2.5/weather?q=broome&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #199: san vicente
# http://api.openweathermap.org/data/2.5/weather?q=san vicente&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #200: grand centre
# http://api.openweathermap.org/data/2.5/weather?q=grand centre&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #201: axim
# http://api.openweathermap.org/data/2.5/weather?q=axim&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #202: wattegama
# http://api.openweathermap.org/data/2.5/weather?q=wattegama&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #203: vao
# http://api.openweathermap.org/data/2.5/weather?q=vao&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #204: plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?q=plettenberg bay&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #205: rocha
# http://api.openweathermap.org/data/2.5/weather?q=rocha&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #206: luderitz
# http://api.openweathermap.org/data/2.5/weather?q=luderitz&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #207: carauari
# http://api.openweathermap.org/data/2.5/weather?q=carauari&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #208: vrangel
# http://api.openweathermap.org/data/2.5/weather?q=vrangel&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #209: half moon bay
# http://api.openweathermap.org/data/2.5/weather?q=half moon bay&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #210: creel
# http://api.openweathermap.org/data/2.5/weather?q=creel&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #211: hamilton
# http://api.openweathermap.org/data/2.5/weather?q=hamilton&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #212: jumla
# http://api.openweathermap.org/data/2.5/weather?q=jumla&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #213: goderich
# http://api.openweathermap.org/data/2.5/weather?q=goderich&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #214: pevek
# http://api.openweathermap.org/data/2.5/weather?q=pevek&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #215: husavik
# http://api.openweathermap.org/data/2.5/weather?q=husavik&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #216: victoria
# http://api.openweathermap.org/data/2.5/weather?q=victoria&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #217: iberia
# http://api.openweathermap.org/data/2.5/weather?q=iberia&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #218: saraland
# http://api.openweathermap.org/data/2.5/weather?q=saraland&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #219: tsihombe
# http://api.openweathermap.org/data/2.5/weather?q=tsihombe&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #220: bereda
# http://api.openweathermap.org/data/2.5/weather?q=bereda&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #221: zhezkazgan
# http://api.openweathermap.org/data/2.5/weather?q=zhezkazgan&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #222: kargopol
# http://api.openweathermap.org/data/2.5/weather?q=kargopol&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #223: port hedland
# http://api.openweathermap.org/data/2.5/weather?q=port hedland&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #224: zhangye
# http://api.openweathermap.org/data/2.5/weather?q=zhangye&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #225: touros
# http://api.openweathermap.org/data/2.5/weather?q=touros&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #226: sungairaya
# http://api.openweathermap.org/data/2.5/weather?q=sungairaya&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #227: los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?q=los llanos de aridane&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #228: palaikastron
# http://api.openweathermap.org/data/2.5/weather?q=palaikastron&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #229: bengkulu
# http://api.openweathermap.org/data/2.5/weather?q=bengkulu&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #230: cagayan de tawi-tawi
# http://api.openweathermap.org/data/2.5/weather?q=cagayan de tawi-tawi&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #231: tubmanburg
# http://api.openweathermap.org/data/2.5/weather?q=tubmanburg&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #232: bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?q=bandarbeyla&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #233: toliary
# http://api.openweathermap.org/data/2.5/weather?q=toliary&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #234: selma
# http://api.openweathermap.org/data/2.5/weather?q=selma&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #235: lavrentiya
# http://api.openweathermap.org/data/2.5/weather?q=lavrentiya&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #236: argentan
# http://api.openweathermap.org/data/2.5/weather?q=argentan&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #237: saint-joseph
# http://api.openweathermap.org/data/2.5/weather?q=saint-joseph&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #238: omsukchan
# http://api.openweathermap.org/data/2.5/weather?q=omsukchan&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #239: inta
# http://api.openweathermap.org/data/2.5/weather?q=inta&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #240: matara
# http://api.openweathermap.org/data/2.5/weather?q=matara&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #241: makakilo city
# http://api.openweathermap.org/data/2.5/weather?q=makakilo city&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #242: kargasok
# http://api.openweathermap.org/data/2.5/weather?q=kargasok&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #243: santa vitoria do palmar
# http://api.openweathermap.org/data/2.5/weather?q=santa vitoria do palmar&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #244: dumas
# http://api.openweathermap.org/data/2.5/weather?q=dumas&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #245: saint anthony
# http://api.openweathermap.org/data/2.5/weather?q=saint anthony&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #246: dunedin
# http://api.openweathermap.org/data/2.5/weather?q=dunedin&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #247: pervoye maya
# http://api.openweathermap.org/data/2.5/weather?q=pervoye maya&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #248: aripuana
# http://api.openweathermap.org/data/2.5/weather?q=aripuana&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #249: saint stephen
# http://api.openweathermap.org/data/2.5/weather?q=saint stephen&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #250: kavieng
# http://api.openweathermap.org/data/2.5/weather?q=kavieng&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #251: trofors
# http://api.openweathermap.org/data/2.5/weather?q=trofors&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #252: wanaka
# http://api.openweathermap.org/data/2.5/weather?q=wanaka&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #253: wroclaw
# http://api.openweathermap.org/data/2.5/weather?q=wroclaw&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #254: vostok
# http://api.openweathermap.org/data/2.5/weather?q=vostok&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #255: beaverlodge
# http://api.openweathermap.org/data/2.5/weather?q=beaverlodge&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #256: vaitupu
# http://api.openweathermap.org/data/2.5/weather?q=vaitupu&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #257: port hardy
# http://api.openweathermap.org/data/2.5/weather?q=port hardy&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #258: ouallam
# http://api.openweathermap.org/data/2.5/weather?q=ouallam&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #259: karagay
# http://api.openweathermap.org/data/2.5/weather?q=karagay&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #260: kisangani
# http://api.openweathermap.org/data/2.5/weather?q=kisangani&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #261: santa maria
# http://api.openweathermap.org/data/2.5/weather?q=santa maria&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #262: nome
# http://api.openweathermap.org/data/2.5/weather?q=nome&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #263: inhambane
# http://api.openweathermap.org/data/2.5/weather?q=inhambane&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #264: novikovo
# http://api.openweathermap.org/data/2.5/weather?q=novikovo&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #265: libreville
# http://api.openweathermap.org/data/2.5/weather?q=libreville&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #266: tecoanapa
# http://api.openweathermap.org/data/2.5/weather?q=tecoanapa&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #267: palencia
# http://api.openweathermap.org/data/2.5/weather?q=palencia&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #268: marcona
# http://api.openweathermap.org/data/2.5/weather?q=marcona&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #269: kamenka
# http://api.openweathermap.org/data/2.5/weather?q=kamenka&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #270: newport
# http://api.openweathermap.org/data/2.5/weather?q=newport&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #271: wageningen
# http://api.openweathermap.org/data/2.5/weather?q=wageningen&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #272: sitka
# http://api.openweathermap.org/data/2.5/weather?q=sitka&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #273: osasco
# http://api.openweathermap.org/data/2.5/weather?q=osasco&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #274: tenkodogo
# http://api.openweathermap.org/data/2.5/weather?q=tenkodogo&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #275: rondonopolis
# http://api.openweathermap.org/data/2.5/weather?q=rondonopolis&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #276: atar
# http://api.openweathermap.org/data/2.5/weather?q=atar&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #277: balikpapan
# http://api.openweathermap.org/data/2.5/weather?q=balikpapan&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #278: azuqueca de henares
# http://api.openweathermap.org/data/2.5/weather?q=azuqueca de henares&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #279: padang
# http://api.openweathermap.org/data/2.5/weather?q=padang&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #280: hengyang
# http://api.openweathermap.org/data/2.5/weather?q=hengyang&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #281: zalari
# http://api.openweathermap.org/data/2.5/weather?q=zalari&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #282: port elizabeth
# http://api.openweathermap.org/data/2.5/weather?q=port elizabeth&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #283: karatau
# http://api.openweathermap.org/data/2.5/weather?q=karatau&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #284: clyde river
# http://api.openweathermap.org/data/2.5/weather?q=clyde river&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #285: elat
# http://api.openweathermap.org/data/2.5/weather?q=elat&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #286: samarai
# http://api.openweathermap.org/data/2.5/weather?q=samarai&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #287: ust-nera
# http://api.openweathermap.org/data/2.5/weather?q=ust-nera&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #288: vanimo
# http://api.openweathermap.org/data/2.5/weather?q=vanimo&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #289: mikkeli
# http://api.openweathermap.org/data/2.5/weather?q=mikkeli&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #290: villa guerrero
# http://api.openweathermap.org/data/2.5/weather?q=villa guerrero&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #291: nuzvid
# http://api.openweathermap.org/data/2.5/weather?q=nuzvid&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #292: warrington
# http://api.openweathermap.org/data/2.5/weather?q=warrington&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #293: klyuchi
# http://api.openweathermap.org/data/2.5/weather?q=klyuchi&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #294: krasnoselkup
# http://api.openweathermap.org/data/2.5/weather?q=krasnoselkup&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #295: utiel
# http://api.openweathermap.org/data/2.5/weather?q=utiel&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #296: emba
# http://api.openweathermap.org/data/2.5/weather?q=emba&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #297: barrow
# http://api.openweathermap.org/data/2.5/weather?q=barrow&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #298: talnakh
# http://api.openweathermap.org/data/2.5/weather?q=talnakh&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #299: jinchang
# http://api.openweathermap.org/data/2.5/weather?q=jinchang&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #300: awjilah
# http://api.openweathermap.org/data/2.5/weather?q=awjilah&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #301: berlevag
# http://api.openweathermap.org/data/2.5/weather?q=berlevag&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #302: dawlatabad
# http://api.openweathermap.org/data/2.5/weather?q=dawlatabad&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #303: salym
# http://api.openweathermap.org/data/2.5/weather?q=salym&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #304: vardo
# http://api.openweathermap.org/data/2.5/weather?q=vardo&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #305: rio gallegos
# http://api.openweathermap.org/data/2.5/weather?q=rio gallegos&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #306: kuala terengganu
# http://api.openweathermap.org/data/2.5/weather?q=kuala terengganu&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #307: paraiso
# http://api.openweathermap.org/data/2.5/weather?q=paraiso&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #308: sataua
# http://api.openweathermap.org/data/2.5/weather?q=sataua&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #309: el molino
# http://api.openweathermap.org/data/2.5/weather?q=el molino&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #310: cherskiy
# http://api.openweathermap.org/data/2.5/weather?q=cherskiy&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #311: yazykovo
# http://api.openweathermap.org/data/2.5/weather?q=yazykovo&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #312: henties bay
# http://api.openweathermap.org/data/2.5/weather?q=henties bay&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #313: salvacion
# ...
# Now retrieving city #510: linguere
# http://api.openweathermap.org/data/2.5/weather?q=linguere&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #511: susehri
# http://api.openweathermap.org/data/2.5/weather?q=susehri&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #512: olinda
# http://api.openweathermap.org/data/2.5/weather?q=olinda&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #513: asau
# http://api.openweathermap.org/data/2.5/weather?q=asau&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #514: dwarka
# http://api.openweathermap.org/data/2.5/weather?q=dwarka&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #515: ca mau
# http://api.openweathermap.org/data/2.5/weather?q=ca mau&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #516: lasa
# http://api.openweathermap.org/data/2.5/weather?q=lasa&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #517: cabra
# http://api.openweathermap.org/data/2.5/weather?q=cabra&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #518: bonavista
# http://api.openweathermap.org/data/2.5/weather?q=bonavista&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #519: chuy
# http://api.openweathermap.org/data/2.5/weather?q=chuy&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #520: belaya gora
# http://api.openweathermap.org/data/2.5/weather?q=belaya gora&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #521: solnechnyy
# http://api.openweathermap.org/data/2.5/weather?q=solnechnyy&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #522: kaniama
# http://api.openweathermap.org/data/2.5/weather?q=kaniama&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #523: tateyama
# http://api.openweathermap.org/data/2.5/weather?q=tateyama&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #524: hinton
# http://api.openweathermap.org/data/2.5/weather?q=hinton&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #525: oxapampa
# http://api.openweathermap.org/data/2.5/weather?q=oxapampa&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #526: evinayong
# http://api.openweathermap.org/data/2.5/weather?q=evinayong&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #527: camacupa
# http://api.openweathermap.org/data/2.5/weather?q=camacupa&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #528: turochak
# http://api.openweathermap.org/data/2.5/weather?q=turochak&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #529: da nang
# http://api.openweathermap.org/data/2.5/weather?q=da nang&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #530: richards bay
# http://api.openweathermap.org/data/2.5/weather?q=richards bay&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #531: praia
# http://api.openweathermap.org/data/2.5/weather?q=praia&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #532: haines junction
# http://api.openweathermap.org/data/2.5/weather?q=haines junction&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #533: craigieburn
# http://api.openweathermap.org/data/2.5/weather?q=craigieburn&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #534: charters towers
# http://api.openweathermap.org/data/2.5/weather?q=charters towers&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #535: arlit
# http://api.openweathermap.org/data/2.5/weather?q=arlit&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #536: kamenskoye
# http://api.openweathermap.org/data/2.5/weather?q=kamenskoye&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #537: ta khmau
# http://api.openweathermap.org/data/2.5/weather?q=ta khmau&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #538: shu
# http://api.openweathermap.org/data/2.5/weather?q=shu&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #539: neuquen
# http://api.openweathermap.org/data/2.5/weather?q=neuquen&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #540: nemuro
# http://api.openweathermap.org/data/2.5/weather?q=nemuro&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #541: tiarei
# http://api.openweathermap.org/data/2.5/weather?q=tiarei&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #542: ruatoria
# http://api.openweathermap.org/data/2.5/weather?q=ruatoria&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #543: blairmore
# http://api.openweathermap.org/data/2.5/weather?q=blairmore&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #544: tatarskaya pishlya
# http://api.openweathermap.org/data/2.5/weather?q=tatarskaya pishlya&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #545: ballina
# http://api.openweathermap.org/data/2.5/weather?q=ballina&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #546: ichchapuram
# http://api.openweathermap.org/data/2.5/weather?q=ichchapuram&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #547: hargeysa
# http://api.openweathermap.org/data/2.5/weather?q=hargeysa&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #548: mier
# http://api.openweathermap.org/data/2.5/weather?q=mier&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #549: kalianget
# http://api.openweathermap.org/data/2.5/weather?q=kalianget&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #550: kjollefjord
# http://api.openweathermap.org/data/2.5/weather?q=kjollefjord&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #551: jacareacanga
# http://api.openweathermap.org/data/2.5/weather?q=jacareacanga&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #552: cap malheureux
# http://api.openweathermap.org/data/2.5/weather?q=cap malheureux&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #553: sorland
# http://api.openweathermap.org/data/2.5/weather?q=sorland&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #554: tabiauea
# http://api.openweathermap.org/data/2.5/weather?q=tabiauea&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #555: hervey bay
# http://api.openweathermap.org/data/2.5/weather?q=hervey bay&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #556: alotau
# http://api.openweathermap.org/data/2.5/weather?q=alotau&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #557: kota bahru
# http://api.openweathermap.org/data/2.5/weather?q=kota bahru&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #558: kahului
# http://api.openweathermap.org/data/2.5/weather?q=kahului&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #559: dingle
# http://api.openweathermap.org/data/2.5/weather?q=dingle&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #560: shonguy
# http://api.openweathermap.org/data/2.5/weather?q=shonguy&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #561: marrakesh
# http://api.openweathermap.org/data/2.5/weather?q=marrakesh&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #562: margate
# http://api.openweathermap.org/data/2.5/weather?q=margate&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #563: urengoy
# http://api.openweathermap.org/data/2.5/weather?q=urengoy&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #564: maragogi
# http://api.openweathermap.org/data/2.5/weather?q=maragogi&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #565: lethem
# http://api.openweathermap.org/data/2.5/weather?q=lethem&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #566: ozgon
# http://api.openweathermap.org/data/2.5/weather?q=ozgon&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #567: ust-kamchatsk
# http://api.openweathermap.org/data/2.5/weather?q=ust-kamchatsk&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #568: fare
# http://api.openweathermap.org/data/2.5/weather?q=fare&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #569: severnoye
# http://api.openweathermap.org/data/2.5/weather?q=severnoye&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #570: kattivakkam
# http://api.openweathermap.org/data/2.5/weather?q=kattivakkam&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #571: port keats
# http://api.openweathermap.org/data/2.5/weather?q=port keats&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #572: bilma
# http://api.openweathermap.org/data/2.5/weather?q=bilma&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #573: san lorenzo
# http://api.openweathermap.org/data/2.5/weather?q=san lorenzo&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #574: dorog
# http://api.openweathermap.org/data/2.5/weather?q=dorog&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #575: staroaleyskoye
# http://api.openweathermap.org/data/2.5/weather?q=staroaleyskoye&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #576: honningsvag
# http://api.openweathermap.org/data/2.5/weather?q=honningsvag&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #577: topeka
# http://api.openweathermap.org/data/2.5/weather?q=topeka&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #578: mossendjo
# http://api.openweathermap.org/data/2.5/weather?q=mossendjo&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #579: sur
# http://api.openweathermap.org/data/2.5/weather?q=sur&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #580: vilyuysk
# http://api.openweathermap.org/data/2.5/weather?q=vilyuysk&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #581: miraflores
# http://api.openweathermap.org/data/2.5/weather?q=miraflores&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #582: dudinka
# http://api.openweathermap.org/data/2.5/weather?q=dudinka&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #583: lata
# http://api.openweathermap.org/data/2.5/weather?q=lata&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #584: pinega
# http://api.openweathermap.org/data/2.5/weather?q=pinega&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #585: danilov
# http://api.openweathermap.org/data/2.5/weather?q=danilov&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #586: oyama
# http://api.openweathermap.org/data/2.5/weather?q=oyama&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #587: leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?q=leshukonskoye&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #588: ternate
# http://api.openweathermap.org/data/2.5/weather?q=ternate&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #589: sheridan
# http://api.openweathermap.org/data/2.5/weather?q=sheridan&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #590: tarudant
# http://api.openweathermap.org/data/2.5/weather?q=tarudant&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #591: savinka
# http://api.openweathermap.org/data/2.5/weather?q=savinka&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #592: safaga
# http://api.openweathermap.org/data/2.5/weather?q=safaga&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.
# Now retrieving city #593: fort nelson
# http://api.openweathermap.org/data/2.5/weather?q=fort nelson&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #594: marsh harbour
# http://api.openweathermap.org/data/2.5/weather?q=marsh harbour&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #595: saint-augustin
# http://api.openweathermap.org/data/2.5/weather?q=saint-augustin&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #596: orissaare
# http://api.openweathermap.org/data/2.5/weather?q=orissaare&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #597: inverell
# http://api.openweathermap.org/data/2.5/weather?q=inverell&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #598: kibre mengist
# http://api.openweathermap.org/data/2.5/weather?q=kibre mengist&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #599: ola
# http://api.openweathermap.org/data/2.5/weather?q=ola&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #600: nsoko
# http://api.openweathermap.org/data/2.5/weather?q=nsoko&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #601: yarada
# http://api.openweathermap.org/data/2.5/weather?q=yarada&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #602: boguchany
# http://api.openweathermap.org/data/2.5/weather?q=boguchany&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #603: sambava
# http://api.openweathermap.org/data/2.5/weather?q=sambava&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #604: gusev
# http://api.openweathermap.org/data/2.5/weather?q=gusev&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #605: mount isa
# http://api.openweathermap.org/data/2.5/weather?q=mount isa&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #606: warri
# http://api.openweathermap.org/data/2.5/weather?q=warri&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #607: norton shores
# http://api.openweathermap.org/data/2.5/weather?q=norton shores&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #608: mandurah
# http://api.openweathermap.org/data/2.5/weather?q=mandurah&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #609: aksay
# http://api.openweathermap.org/data/2.5/weather?q=aksay&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #610: imeni zhelyabova
# http://api.openweathermap.org/data/2.5/weather?q=imeni zhelyabova&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #611: nizhnevartovsk
# http://api.openweathermap.org/data/2.5/weather?q=nizhnevartovsk&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #612: angoche
# http://api.openweathermap.org/data/2.5/weather?q=angoche&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #613: juneau
# http://api.openweathermap.org/data/2.5/weather?q=juneau&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #614: bukachacha
# http://api.openweathermap.org/data/2.5/weather?q=bukachacha&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #615: lieksa
# http://api.openweathermap.org/data/2.5/weather?q=lieksa&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# Now retrieving city #616: warqla
# http://api.openweathermap.org/data/2.5/weather?q=warqla&units=IMPERIAL&appid=e6af85a83d931ec6f1f1eec9ec5ec3cf
# error skip.

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_data["Date"] = pd.to_datetime(cities_data["Date"], unit='s')
cities_data = cities_data.dropna(axis=0, how='any')
cities_data.head()
# Out:
#             City    Lat     Lon                Date   Temp Humidity  \
# 0        rikitea -23.12 -134.97 2019-07-01 19:59:41  69.01       66
# 1         geneva   46.2    6.15 2019-07-01 20:07:34  75.67       48
# 3  leningradskiy  69.38  178.42 2019-07-01 20:00:48  39.85       95
# 4       saldanha  41.42   -6.55 2019-07-01 20:00:51  72.61       62
# 5         tiznit   29.7   -9.73 2019-07-01 20:07:35  66.49       88
#
#   Cloudiness Windspeed
# 0        100     15.75
# 1         75      6.93
# 3        100      6.46
# 4          0      4.07
# 5          0     12.59

# %%
cities_data.to_csv("cities_data.csv", index=False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(x=cities_data["Lat"],y=cities_data["Temp"] , marker="o", facecolors="blue", edgecolors="black", alpha = 1)
plt.title("Latitude v. Temperature")
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.savefig("LatitudeTemperature.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(x=cities_data['Lat'],y=cities_data['Humidity'] , marker="o", facecolors="blue", edgecolors="black", alpha = 1)
plt.title("Latitude v. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.savefig("Latitude v. Humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(x=cities_data["Lat"], y=cities_data["Cloudiness"], marker="o", facecolors="blue", edgecolors="black", alpha = 1)
plt.title("Latitude v. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.savefig("Latitude v. Cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(x=cities_data["Lat"],y=cities_data["Windspeed"] , marker="o", facecolors="blue", edgecolors="black", alpha = 1)
plt.title("Latitude v. Windspeed")
plt.xlabel("Latitude")
plt.ylabel("Windspeed")
plt.savefig("Latitude v. Windspeed.png")
plt.show()
